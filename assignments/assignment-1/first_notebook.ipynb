# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Graph Algorithms

# %%
names = "Fikernew Birhanu Waju".split()

# %%
names_length = [ len(name) for name in names ]

# %%
plt.bar(names, names_length)
plt.show()
